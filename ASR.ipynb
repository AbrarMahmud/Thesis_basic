# %% [markdown]
# <a href="https://colab.research.google.com/github/AbrarMahmud/Thesis_basic/blob/main/ASR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pre-trained models for automatic speech recognition
# Model:
# #Wisper by OpenAi

# %%
# !pip install datasets

# %%
from datasets import load_dataset

dataset = load_dataset(
    "hf-internal-testing/librispeech_asr_dummy", "clean", split="validation"
)
dataset
# Out:
# Dataset({
#     features: ['file', 'audio', 'text', 'speaker_id', 'chapter_id', 'id'],
#     num_rows: 73
# })

# %% [markdown]
# The Whisper checkpoints come in five configurations of varying model sizes:
#
# ![image.png](data:image/png;base64,...)
#
# “VRAM” denotes the required GPU memory to run the model with the **minimum batch size of 1.** “Rel Speed” is the relative speed of a checkpoint compared to the largest model
